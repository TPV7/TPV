# %%
import networkx as nx 
import matplotlib.pyplot as plt 
CM=nx.DiGraph()
CM.add_nodes_from(['association class','M-to-M associations','domain model class diagrams','process modeling','activity diagrams','system sequence diagram'])

CM.add_edges_from([('association class','M-to-M associations')],label='stores information for SDLC')
CM.add_edges_from([('system sequence diagram','process modeling')],label='are implimented and used by')
CM.add_edges_from([('Domain model class diagram','M-to-M associations')],label='are related to SDLF')
CM.add_edges_from([('system sequence diagram','activity diagram')],label='is part of')
CM.add_edges_from([('process modeling','domain model class diagrams')],label='are related to SDLF')
edgelabels=nx.get_edge_attributes(CM,'label')
plt.figure(1, figsize=(8,8))
pos=nx.circular_layout(CM)
nx.draw (CM, pos, arrows=True, node_size=3000, node_color='Blue', with_labels=True, edge_color='green')
nx.draw_networkx_edge_labels(CM, pos, edge_labels= edgelabel, label_pos=0.5, font_size=11)
plt.show()
